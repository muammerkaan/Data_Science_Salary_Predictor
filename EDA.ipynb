# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("glassdoor_jobs_cleaned.csv")

# %%
df.head()
# Out:
#                                         Job Title  \
# 0                                  Data Scientist
# 1  Associate Business Intelligence Data Scientist
# 2                  Scientist, Population Genomics
# 3                                 Data Analyst II
# 4                               Sensory Scientist
#
#                Salary Estimate  \
# 0  $64K-$106K (Glassdoor est.)
# 1  $64K-$106K (Glassdoor est.)
# 2  $64K-$106K (Glassdoor est.)
# 3  $64K-$106K (Glassdoor est.)
# 4  $64K-$106K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 1  Blending customer advisory, customer support, ...     3.2
# 2  WuXi NextCODE is seeking a motivated Scientist...     2.9
# 3  The Data Analyst II is responsible for data en...     4.2
# 4  A leading food production company in St. Louis...     3.8
#
#                 Company Name         Location   Headquarters  \
# 0                    ManTech    Chantilly, VA    Herndon, VA
# 1        Carousel Industries       Exeter, RI     Exeter, RI
# 2        Carousel Industries    Cambridge, MA  Cambridge, MA
# 3  Insight Enterprises, Inc.        Plano, TX      Tempe, AZ
# 4                NIC Infotek  Saint Louis, MO      Tampa, FL
#
#                       Size  Founded  Type of ownership  ... pytorch_yn  \
# 0  5001 to 10000 employees     1968   Company - Public  ...          0
# 1   1001 to 5000 employees     1992  Company - Private  ...          0
# 2    501 to 1000 employees     2015  Company - Private  ...          0
# 3  5001 to 10000 employees     1988   Company - Public  ...          0
# 4      51 to 200 employees     2004   Company - Public  ...          0
#
#   algo_yn stats_yn tableau_yn        job_type  job_type_num  seniority  \
# 0       1        1          0  data scientist             3         na
# 1       0        1          1  data scientist             3         na
# 2       0        1          0              na             7         na
# 3       0        0          0         analyst             1         na
# 4       0        1          0              na             7         na
#
#   seniority_num  len_desc  num_comp
# 0             2      3962         0
# 1             2      5358         0
# 2             2      3183         0
# 3             2      4218         3
# 4             2      1833         0
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'State', 'jobhq', 'age',
#        'python_yn', 'r_yn', 'aws_yn', 'spark_yn', 'hadoop_yn', 'docker_yn',
#        'sql_yn', 'linux_yn', 'flask_yn', 'django_yn', 'tensorflow_yn',
#        'keras_yn', 'pytorch_yn', 'algo_yn', 'stats_yn', 'tableau_yn',
#        'job_type', 'job_type_num', 'seniority', 'seniority_num', 'len_desc',
#        'num_comp'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Rating      Founded  min_salary  max_salary  avg_salary  \
# count  940.000000   940.000000  940.000000  940.000000  940.000000
# mean     3.868191  1787.376596   87.503191  136.112766  111.807979
# std      0.622697   590.838475   22.219953   35.119756   27.917708
# min      1.500000    -1.000000   55.000000   69.000000   63.500000
# 25%      3.500000  1951.000000   64.000000  101.000000   85.000000
# 50%      3.900000  1995.000000   96.000000  140.000000  124.000000
# 75%      4.300000  2007.250000   99.000000  156.000000  126.500000
# max      5.000000  2019.000000  141.000000  225.000000  183.000000
#
#             jobhq         age   python_yn        r_yn      aws_yn  ...  \
# count  940.000000  940.000000  940.000000  940.000000  940.000000  ...
# mean     0.454255   34.725532    0.745745    0.426596    0.268085  ...
# std      0.498168   43.299059    0.435674    0.494846    0.443198  ...
# min      0.000000   -1.000000    0.000000    0.000000    0.000000  ...
# 25%      0.000000    8.000000    0.000000    0.000000    0.000000  ...
# 50%      0.000000   21.000000    1.000000    0.000000    0.000000  ...
# 75%      1.000000   42.000000    1.000000    1.000000    1.000000  ...
# max      1.000000  330.000000    1.000000    1.000000    1.000000  ...
#
#        tensorflow_yn    keras_yn  pytorch_yn     algo_yn    stats_yn  \
# count     940.000000  940.000000  940.000000  940.000000  940.000000
# mean        0.168085    0.068085    0.092553    0.411702    0.719149
# std         0.374141    0.252026    0.289960    0.492404    0.449654
# min         0.000000    0.000000    0.000000    0.000000    0.000000
# 25%         0.000000    0.000000    0.000000    0.000000    0.000000
# 50%         0.000000    0.000000    0.000000    0.000000    1.000000
# 75%         0.000000    0.000000    0.000000    1.000000    1.000000
# max         1.000000    1.000000    1.000000    1.000000    1.000000
#
#        tableau_yn  job_type_num  seniority_num      len_desc    num_comp
# count  940.000000    940.000000     940.000000    940.000000  940.000000
# mean     0.190426      3.294681       1.827660   3624.280851    0.869149
# std      0.392846      1.471553       0.377877   1674.938897    1.280186
# min      0.000000      1.000000       1.000000    119.000000    0.000000
# 25%      0.000000      3.000000       2.000000   2627.000000    0.000000
# 50%      0.000000      3.000000       2.000000   3508.000000    0.000000
# 75%      0.000000      3.000000       2.000000   4424.500000    2.000000
# max      1.000000      9.000000       2.000000  14110.000000    3.000000
#
# [8 rows x 27 columns]

# %%
df['Rating'].hist(grid=False)
# Out:
# <AxesSubplot: >

# %% [markdown]
# There doesn't seem to be too many ratings on the lower side, and the histogram does seem right skewed.

# %%
df.avg_salary.hist(bins=6,grid=False)
# Out:
# <AxesSubplot: >

# %% [markdown]
# This plot shows a lot of jobs in the \\$60,000 to \\$100,000 range and an even higher number in the \\$120,000 to \\$140,000 range, but very few jobs in the \\$100,000 to \\$120,000 range, which might indicate a clear distinction in salary between the junior and senior levels.

# %%
df.age.hist(bins=15,grid=False)
# Out:
# <AxesSubplot: >

# %% [markdown]
# A clearly left-skewed graph, most companies hiring seem to be founded more recently, most of them between 0 and 50 years old.

# %%
df.len_desc.hist(grid=False)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Most descriptions for jobs seem to be around 4000 words long, but some descriptions seem to go on for 14,000 words as well!

# %%
sns.scatterplot(x=df.len_desc,y=df.age,hue=df.avg_salary)
# Out:
# <AxesSubplot: xlabel='len_desc', ylabel='age'>

# %% [markdown]
# A very cluttered plot, the only thing to focus on are the outliers:
# The really long descriptions are jobs that probably won't pay as much as the others.
# The really old companies (200+ years) actually keep their descriptions short, and also pay on a higher scale typically.

# %%
df.boxplot(column=['age','avg_salary'])
# Out:
# <AxesSubplot: >

# %%
df.boxplot(column='Rating')
# Out:
# <AxesSubplot: >

# %% [markdown]
# These boxplots show that age has a lot of outliers on the higher side, rating has a few on the lower side, while average salary has a very uniform distribution.

# %%
c1=df[['age','avg_salary','Rating','len_desc','num_comp']].corr()
c1
# Out:
#                  age  avg_salary    Rating  len_desc  num_comp
# age         1.000000    0.019714 -0.152492  0.181225  0.182292
# avg_salary  0.019714    1.000000  0.050819 -0.073773 -0.023767
# Rating     -0.152492    0.050819  1.000000 -0.103349 -0.084715
# len_desc    0.181225   -0.073773 -0.103349  1.000000  0.144077
# num_comp    0.182292   -0.023767 -0.084715  0.144077  1.000000

# %%
f, ax = plt.subplots(figsize=(8, 5))
mask = np.triu(np.ones_like(c1, dtype=np.bool))
cmap=sns.diverging_palette(220,10,as_cmap=True)
sns.heatmap(c1,vmax=.3,center=0,cmap="YlGnBu",mask=mask,square=True,linewidths=.5,cbar_kws={"shrink": .5},annot=True)
# Out:
# <ipython-input-15-432e0a0a65c9>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(c1, dtype=np.bool))
# <AxesSubplot: >

# %% [markdown]
# Although there are no strong correlations, Description Length, Age and Number of Competitors seem to be slightly correlated.

# %%
sns.pairplot(df[['age','avg_salary','Rating','len_desc','num_comp']])

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'State', 'jobhq', 'age',
#        'python_yn', 'r_yn', 'aws_yn', 'spark_yn', 'hadoop_yn', 'docker_yn',
#        'sql_yn', 'linux_yn', 'flask_yn', 'django_yn', 'tensorflow_yn',
#        'keras_yn', 'pytorch_yn', 'algo_yn', 'stats_yn', 'tableau_yn',
#        'job_type', 'job_type_num', 'seniority', 'seniority_num', 'len_desc',
#        'num_comp'],
#       dtype='object')

# %%
df_cat=df[['Location','Headquarters','Size','Type of ownership','Industry','Sector','Revenue','Company Name',
           'State','python_yn','r_yn','aws_yn','spark_yn', 'hadoop_yn', 'docker_yn',
       'sql_yn', 'linux_yn', 'flask_yn', 'django_yn', 'tensorflow_yn',
       'keras_yn', 'pytorch_yn', 'algo_yn', 'stats_yn', 'tableau_yn',
       'job_type', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total = 243
# graph for Headquarters: total = 266
# graph for Size: total = 8
# graph for Type of ownership: total = 12
# graph for Industry: total = 62
# graph for Sector: total = 23
# graph for Revenue: total = 13
# graph for Company Name: total = 547
# graph for State: total = 41
# graph for python_yn: total = 2
# graph for r_yn: total = 2
# graph for aws_yn: total = 2
# graph for spark_yn: total = 2
# graph for hadoop_yn: total = 2
# graph for docker_yn: total = 2
# graph for sql_yn: total = 2
# graph for linux_yn: total = 2
# graph for flask_yn: total = 2
# graph for django_yn: total = 2
# graph for tensorflow_yn: total = 2
# graph for keras_yn: total = 2
# graph for pytorch_yn: total = 2
# graph for algo_yn: total = 2
# graph for stats_yn: total = 2
# graph for tableau_yn: total = 2
# graph for job_type: total = 9
# graph for seniority: total = 2

# %%
for i in df[['Location','Headquarters','Industry','Company Name']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print("graph for %s: The Top %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: The Top 20
# graph for Headquarters: The Top 20
# graph for Industry: The Top 20
# graph for Company Name: The Top 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'State', 'jobhq', 'age',
#        'python_yn', 'r_yn', 'aws_yn', 'spark_yn', 'hadoop_yn', 'docker_yn',
#        'sql_yn', 'linux_yn', 'flask_yn', 'django_yn', 'tensorflow_yn',
#        'keras_yn', 'pytorch_yn', 'algo_yn', 'stats_yn', 'tableau_yn',
#        'job_type', 'job_type_num', 'seniority', 'seniority_num', 'len_desc',
#        'num_comp'],
#       dtype='object')

# %%
pd.pivot_table(df,index='job_type',values='avg_salary',aggfunc=[np.min,np.max,np.mean,np.std])
# Out:
#                      amin       amax        mean        std
#                avg_salary avg_salary  avg_salary avg_salary
# job_type
# analyst              63.5      183.0   99.093220  28.392640
# data engineer        63.5      152.5  101.119403  27.786809
# data scientist       63.5      183.0  116.101164  27.231654
# director             76.5      152.5   94.562500  28.812742
# manager              76.5       99.0   83.187500   9.698813
# mle                  63.5      152.5   98.369565  27.180883
# na                   63.5      152.5  104.047945  25.143776
# research             76.5      126.5   91.115385  17.978174
# sw                  125.5      126.5  126.000000   0.707107

# %% [markdown]
# Data Scientists have an average salary of \\$116,000 while Data Engineers have an average salary of \\$101,000. Analysts, have an average salary of \\$99,000. Surprisingly, Directors and Managers are being paid slightly less, although this could be a fault with the estimate that Glassdoor has provided.

# %%
pd.pivot_table(df,index=['job_type','seniority'],values='avg_salary')
# Out:
#                           avg_salary
# job_type       seniority
# analyst        na          93.869048
#                senior     112.000000
# data engineer  na         102.231481
#                senior      96.500000
# data scientist na         116.924115
#                senior     110.909574
# director       na          90.000000
#                senior     126.500000
# manager        na          80.928571
#                senior      99.000000
# mle            na          98.470588
#                senior      98.083333
# na             na         105.288889
#                senior     102.053571
# research       na          93.000000
#                senior      80.750000
# sw             na         126.000000

# %% [markdown]
# In most cases, it seems like a senior level pays a little bit lesser. Again, this could be because this data is taken during the COVID-19 pandemic, and lesser senior level and more junior level people are being hired.

# %%
pd.pivot_table(df,index='State',values='avg_salary',margins=True,aggfunc=[np.mean,'count'])
# Out:
#               mean      count
#         avg_salary avg_salary
# State
# AL      107.666667          3
# AZ      116.323529         17
# CA      113.806306        222
# CO      119.031250         16
# CT      103.500000          9
# DC      111.388889         27
# FL      108.789474         19
# GA      129.666667          6
# HI      121.555556          9
# IA       77.500000          1
# ID       80.000000          1
# IL      105.452381         42
# IN       93.700000          5
# KS      101.250000          2
# KY      146.000000          1
# MA      110.857143         91
# MD      111.717391         23
# MI      106.600000         10
# MN      109.125000          4
# MO      115.781250         16
# MS       88.000000          2
# NC      105.461538         13
# NE      133.166667          3
# NH      148.000000          2
# NJ      108.205882         17
# NM       78.750000          2
# NY      116.673333         75
# OH      103.964286         14
# OK      105.000000          3
# OR      102.850000         10
# PA      115.045455         22
# RI      115.500000          4
# Remote  114.576923         13
# SC       77.000000          2
# TN      114.250000         12
# TX      114.437500         64
# UT      117.823529         17
# VA      109.435484         93
# WA      107.142857         28
# WI      105.222222         18
# WV       70.250000          2
# All     111.807979        940

# %%
df_piv=df[['Rating','Industry','Sector','Revenue','num_comp','Type of ownership','python_yn','r_yn'
           ,'aws_yn', 'spark_yn', 'hadoop_yn', 'docker_yn','sql_yn', 'linux_yn', 'flask_yn'
           ,'django_yn', 'tensorflow_yn','keras_yn', 'pytorch_yn', 'algo_yn', 'stats_yn', 'tableau_yn','avg_salary']]

# %%
try:
    for i in df_piv.columns:
        print(i)
        print(pd.pivot_table(df_piv,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
except ValueError:
    pass
# Out:
# Rating
#         avg_salary
# Rating
# 1.5     143.500000
# 2.7     136.714286
# 4.3     124.488095
# 4.8     123.470588
# 3.0     122.117647
# 5.0     121.770833
# 4.5     118.010870
# 2.5     117.500000
# 2.2     117.187500
# 4.0     115.525424
# 4.9     115.444444
# 3.1     115.234375
# 3.2     115.086207
# 3.3     114.250000
# 4.6     113.152778
# 3.8     109.932836
# 2.3     109.312500
# 3.6     109.000000
# 3.7     108.966667
# 4.7     108.687500
# 2.9     108.611111
# 4.1     108.570000
# 3.4     107.609091
# 3.5     107.008197
# 4.2     104.638298
# 4.4     104.129630
# 3.9     103.008065
# 2.6      97.916667
# 2.8      94.666667
# 2.0      77.500000
# 2.4      77.000000
# Industry
#                                      avg_salary
# Industry
# Department, Clothing, & Shoe Stores      183.00
# Hotels, Motels, & Resorts                145.50
# Auctions & Galleries                     145.50
# Health Fundraising Organizations         142.75
# Accounting                               136.25
# ...                                         ...
# Mining                                    80.50
# Express Delivery Services                 80.50
# Oil & Gas Services                        77.00
# TV Broadcast & Cable Networks             73.00
# Timber Operations                         73.00
#
# [62 rows x 1 columns]
# Sector
#                                     avg_salary
# Sector
# Travel & Tourism                    145.500000
# Non-Profit                          142.750000
# Accounting & Legal                  134.100000
# Retail                              119.500000
# Education                           118.833333
# -1                                  116.225000
# Construction, Repair & Maintenance  115.750000
# Information Technology              114.658228
# Telecommunications                  114.625000
# Business Services                   113.761494
# Media                               110.312500
# Health Care                         108.971698
# Government                          108.766667
# Finance                             108.421429
# Insurance                           108.305556
# Aerospace & Defense                 107.217391
# Transportation & Logistics          104.300000
# Consumer Services                   103.642857
# Oil, Gas, Energy & Utilities        103.633333
# Agriculture & Forestry              102.333333
# Manufacturing                       101.903846
# Biotech & Pharmaceuticals           101.101695
# Mining & Metals                      80.500000
# Revenue
#                                   avg_salary
# Revenue
# $25 to $50 million (USD)          120.601695
# $5 to $10 million (USD)           118.902778
# Less than $1 million (USD)        118.175000
# $2 to $5 billion (USD)            116.500000
# $10 to $25 million (USD)          114.000000
# Unknown / Non-Applicable          112.325188
# $10+ billion (USD)                111.960177
# $5 to $10 billion (USD)           110.229167
# $1 to $2 billion (USD)            109.741071
# $50 to $100 million (USD)         108.705128
# $500 million to $1 billion (USD)  107.430233
# $1 to $5 million (USD)            106.500000
# $100 to $500 million (USD)        104.601626
# num_comp
#           avg_salary
# num_comp
# 2         117.168675
# 1         112.805556
# 0         111.976115
# 3         109.113744
# Type of ownership
#                                 avg_salary
# Type of ownership
# College / University            127.343750
# Private Practice / Firm         120.458333
# Unknown                         118.500000
# Contract                        116.250000
# Company - Private               112.685092
# Subsidiary or Business Segment  111.275000
# Company - Public                110.362150
# Nonprofit Organization          109.037736
# Government                       97.964286
# Other Organization               89.750000
# Hospital                         75.250000
# Self-employed                    73.000000
# python_yn
#            avg_salary
# python_yn
# 1          113.715407
# 0          106.213389
# r_yn
#       avg_salary
# r_yn
# 1     112.062344
# 0     111.618738
# aws_yn
#         avg_salary
# aws_yn
# 0       112.562500
# 1       109.748016
# spark_yn
#           avg_salary
# spark_yn
# 1         112.080224
# 0         111.699405
# hadoop_yn
#            avg_salary
# hadoop_yn
# 1          112.058233
# 0          111.717800
# docker_yn
#            avg_salary
# docker_yn
# 1           112.37500
# 0           111.79057
# sql_yn
#         avg_salary
# sql_yn
# 1       113.477148
# 0       109.484733
# linux_yn
#           avg_salary
# linux_yn
# 1         116.342391
# 0         111.316038
# flask_yn
#           avg_salary
# flask_yn
# 1         121.714286
# 0         111.658207
# django_yn
#            avg_salary
# django_yn
# 1          125.272727
# 0          111.648547
# tensorflow_yn
#                avg_salary
# tensorflow_yn
# 0              112.012148
# 1              110.797468
# keras_yn
#           avg_salary
# keras_yn
# 1         112.765625
# 0         111.738014
# pytorch_yn
#             avg_salary
# pytorch_yn
# 1           113.833333
# 0           111.601407
# algo_yn
#          avg_salary
# algo_yn
# 1        114.558140
# 0        109.883363
# stats_yn
#           avg_salary
# stats_yn
# 1         114.401627
# 0         105.166667
# tableau_yn
#             avg_salary
# tableau_yn
# 0           112.165572
# 1           110.287709
# avg_salary

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'State', 'jobhq', 'age',
#        'python_yn', 'r_yn', 'aws_yn', 'spark_yn', 'hadoop_yn', 'docker_yn',
#        'sql_yn', 'linux_yn', 'flask_yn', 'django_yn', 'tensorflow_yn',
#        'keras_yn', 'pytorch_yn', 'algo_yn', 'stats_yn', 'tableau_yn',
#        'job_type', 'job_type_num', 'seniority', 'seniority_num', 'len_desc',
#        'num_comp'],
#       dtype='object')

# %%
type(df.jobhq[0])
# Out:
# numpy.int64

# %%
df.seniority.value_counts()
# Out:
# na        778
# senior    162
# Name: seniority, dtype: int64

# %%
df.len_desc.describe()
# Out:
# count      940.000000
# mean      3624.280851
# std       1674.938897
# min        119.000000
# 25%       2627.000000
# 50%       3508.000000
# 75%       4424.500000
# max      14110.000000
# Name: len_desc, dtype: float64

# %%
df['python_yn'].value_counts()
# Out:
# 1    701
# 0    239
# Name: python_yn, dtype: int64
